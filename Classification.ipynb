# %% [markdown]
# <a href="https://colab.research.google.com/github/yibesh/Classification-/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# The first step is loading the Iris dataset

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()

# %%
##if the dataset is in CSV file we can load the data like this

#iris=pd.read_csv("iris.csv")
#iris.head()

# %%
#display the  feature of iris data

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
# Tragets of iris data

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
#display the dataframe of iris data

# %%
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#then diaply input features with tragets

# %%
df['flower_name'] =df.target.apply(lambda x: iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
#display only target 0 data
df[df.target==0].head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
#display only target 1 data
df[df.target==1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target flower_name
# 50       1  versicolor
# 51       1  versicolor
# 52       1  versicolor
# 53       1  versicolor
# 54       1  versicolor

# %%
#display only target 2 data
df[df.target==2].head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target flower_name
# 100       2   virginica
# 101       2   virginica
# 102       2   virginica
# 103       2   virginica
# 104       2   virginica

# %%
df[0:120]  #Just to diplay a number of data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 115                6.4               3.2                5.3               2.3
# 116                6.5               3.0                5.5               1.8
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 119                6.0               2.2                5.0               1.5
#
#      target flower_name
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # **Data Preprocessing and data split**

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['target','flower_name'], axis='columns')
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y = df.target
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(X_train)
# Out:
# 120

# %%
len(X_test)
# Out:
# 30

# %% [markdown]
# # **KNN** **Model**

# %%
# Fitting clasifier to the Training set
# Loading libraries
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import cross_val_score

# Instantiate learning model (k = 3)
classifier = KNeighborsClassifier(n_neighbors=3)

# Fitting the model
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)
print("the prediction results of KNN model are:", y_pred)
# Out:
# [1 2 2 1 2 0 2 0 2 0 2 2 0 2 1 0 0 1 1 2 0 2 2 2 2 1 1 0 1 1]

# %%
#  the actual results

print("the actual results are:", y_test)
# Out:
# the actual results are: 50     1
# 70     1
# 145    2
# 94     1
# 129    2
# 38     0
# 110    2
# 41     0
# 122    2
# 45     0
# 131    2
# 144    2
# 25     0
# 111    2
# 74     1
# 31     0
# 23     0
# 53     1
# 82     1
# 149    2
# 22     0
# 108    2
# 137    2
# 123    2
# 109    2
# 133    2
# 98     1
# 3      0
# 75     1
# 146    2
# Name: target, dtype: int64

# %%
# Evaluating KNN prediction Model

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy of our KNN model is equal ',  accuracy)
# Out:
# Accuracy of our KNN model is equal  0.9

# %%
## Confusion matrix
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       0.78      0.88      0.82         8
#            2       0.92      0.86      0.89        14
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.91      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# # **SVM model**

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
# Create a kernel support vector machine model
svm = SVC(kernel='rbf', gamma=0.1, C=10.0)

# Train the model on the training data
svm.fit(X_train, y_train)

# Predicting the Test set results
pred = svm.predict(X_test)

print("the prediction results of SVM model are:", pred)
# Out:
# [1 2 2 1 2 0 2 0 2 0 2 2 0 2 1 0 0 1 1 2 0 2 2 2 2 1 1 0 1 2]

# %%
#  the actual results

print("the actual results are:", y_test)
# Out:
# the actual results are: 50     1
# 70     1
# 145    2
# 94     1
# 129    2
# 38     0
# 110    2
# 41     0
# 122    2
# 45     0
# 131    2
# 144    2
# 25     0
# 111    2
# 74     1
# 31     0
# 23     0
# 53     1
# 82     1
# 149    2
# 22     0
# 108    2
# 137    2
# 123    2
# 109    2
# 133    2
# 98     1
# 3      0
# 75     1
# 146    2
# Name: target, dtype: int64

# %%
# Evaluating KNN prediction Model

accuracy = accuracy_score(y_test, pred)
print('Accuracy of our KNN model is equal ',  accuracy)
# Out:
# Accuracy of our KNN model is equal  0.9333333333333333

# %%
## Confusion matrix
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       0.88      0.88      0.88         8
#            2       0.93      0.93      0.93        14
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, pred)

plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=20)  #by changing the number of estimators or tree we can imporve the perfromance
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
# Evaluate the model on the test data
accuracy = rf_model.score(X_test, y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.9333333333333333

# %%
#prediction of unseen data
y_predicted = rf_model.predict(X_test)
print(y_predicted)
# Out:
# [0 0 0 1 1 1 2 0 2 2 2 1 2 1 2 0 2 2 2 1 0 0 0 0 1 2 0 2 2 1]

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[10,  0,  0],
#        [ 0,  8,  2],
#        [ 0,  0, 10]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %% [markdown]
# # **Naive_bayes algorthim**

# %%
from sklearn.naive_bayes import GaussianNB
model_Nb = GaussianNB()

# %%
model_Nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model_Nb.score(X_test,y_test)


# Evaluate the model on the test data
accuracy = model_Nb.score(X_test, y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.9333333333333333

# %%
X_test[0:10]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 24                 4.8               3.4                1.9               0.2
# 42                 4.4               3.2                1.3               0.2
# 20                 5.4               3.4                1.7               0.2
# 67                 5.8               2.7                4.1               1.0
# 86                 6.7               3.1                4.7               1.5
# 94                 5.6               2.7                4.2               1.3
# 108                6.7               2.5                5.8               1.8
# 9                  4.9               3.1                1.5               0.1
# 120                6.9               3.2                5.7               2.3
# 70                 5.9               3.2                4.8               1.8

# %%
y_test[0:10]
# Out:
# 24     0
# 42     0
# 20     0
# 67     1
# 86     1
# 94     1
# 108    2
# 9      0
# 120    2
# 70     1
# Name: target, dtype: int64

# %%
#predict unseen data'
prediction=model_Nb.predict(X_test[0:10])
print(prediction)
# Out:
# [0 0 0 1 1 1 2 0 2 2]

# %% [markdown]
# # **Decision Tree Classification**

# %%
import pandas as pd
